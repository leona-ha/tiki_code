# %% [markdown]
# # Check Data Compliance

# %%
import pandas as pd
import datetime as dt
from datetime import date

today = date.today() 
week_ago = today - dt.timedelta(days=7)
today = today.strftime("%d%m%Y")

week_ago = week_ago.strftime("%Y-%m-%d")

datapath = "/Users/leonahammelrath/FU_Psychoinformatik/Github/tiki_code/data/"
filepath = datapath + f"export_{today}.csv"

# %%
df = pd.read_csv(filepath, encoding= "latin-1")

# %%
df.drop(["Quelle", "Created At"], axis=1, inplace=True)

# %%
df["Endkunde"] = df.Endkunde.str.split("@").str.get(0)
df["Endkunde"] = df["Endkunde"].str[:4]
df.rename(columns={"Endkunde":"customer","Tag":"day", "Typ":"type","Wert(Fließkommazahl)": "float", "Wert(Ganzzahl)": "int"}, inplace=True)

# %%
df["day"] = pd.to_datetime(df["day"], format="%d.%m.%Y")

# %%
df["int"].fillna(df["float"], inplace=True)

# %%
df_int= df[["customer", "day", "type", "int"]]

# %%
df_int = df_int.pivot(
    index=["customer", "day"],
    columns="type",
    values="int")

# %%
df_int.reset_index(level="day", inplace=True)

# %%
df_active = pd.read_csv("/Users/leonahammelrath/FU_Psychoinformatik/Github/tiki_code/data/active_participants.csv")

# %%
df_active.rename(columns = {"Pseudonym ": "customer", "EMA ID": "ema_id", "Ende EMA Baseline": "end_ema", "Status": "status",
                            "Start EMA Baseline": "start_ema", "Studienversion":"study_version", "FOR_ID":"for_id"}, inplace=True)

# %%
df_active["customer"] = df_active["customer"].str[:4]

# %%
df_active = df_active[["customer", "ema_id", "end_ema", "start_ema", "study_version", "for_id", "status"]]

# %%
df_active.groupby("status").count()
# Out:
#                   customer  ema_id  end_ema  start_ema  study_version  for_id
# status
# Abgeschlossen           15      15       15         15             15      15
# Dropout                  4       4        4          4              4       4
# Erhebung_1_aktiv         8       8        8          8              8       8
# Post_Erhebung_1         44      44       44         44             44      44

# %%
filepath_connection = f"/Users/leonahammelrath/FU_Psychoinformatik/Github/tiki_code/data/export_connection_{today}.csv"
df_con = pd.read_csv(filepath_connection, encoding= "latin-1")
df_con["Customer"] = df_con.Customer.str.split("@").str.get(0)
df_con["Customer"] = df_con["Customer"].str[:4]
df_con.drop(["Data Source", "Timestamp"], axis=1, inplace=True)
df_con.rename(columns = {"Customer": "customer"}, inplace=True)

# %%
df_complete = pd.merge(df_int, df_active, on="customer")

# %%
df_complete = pd.merge(df_complete, df_con, on="customer")

# %%
grouped = df_complete.groupby(["customer"])["ema_id","for_id","start_ema","end_ema","study_version",
                                            "status","Is Connected","day"].max()
# Out:
# /Users/leonahammelrath/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
grouped_count = df_complete.groupby(["customer"])[["day"]].count()
grouped_count.rename(columns={"day": "nr_days"}, inplace= True)
grouped = pd.merge(grouped, grouped_count, how= "left", on="customer")
grouped
# Out:
#            ema_id      for_id   start_ema     end_ema   study_version  \
# customer
# 0ePW      EMA4006    FOR14007  03.07.2023  17.07.2023            Lang
# 0xWn      EMA2004    FOR12003  27.07.2023  10.08.2023            Lang
# 1rfO      EMA3006    FOR13002  27.06.2023  11.07.2023  Lang (Wechsel)
# 3ZqH      EMA3002  FOR13901\n  20.06.2023  04.07.2023            Kurz
# 3s90      EMA3004    FOR13001  27.06.2023  11.07.2023            Kurz
# ...           ...         ...         ...         ...             ...
# uP59      EMA4036   FOR14027   27.09.2023  11.10.2023            Lang
# vPEr      EMA4010    FOR14013  10.08.2023  24.08.2023            Kurz
# wGQ8      EMA1005    FOR11012  21.06.2023  05.07.2023  Lang (Wechsel)
# xwB7      EMA4011    FOR14012  20.07.2023  03.08.2023            Kurz
# yv0Q      EMA3016   FOR13012   19.09.2023  03.10.2023            Lang
#
#                     status Is Connected        day  nr_days
# customer
# 0ePW       Post_Erhebung_1           ja 2023-09-21       80
# 0xWn       Post_Erhebung_1           ja 2023-10-02       67
# 1rfO       Post_Erhebung_1           ja 2023-07-05        8
# 3ZqH         Abgeschlossen           ja 2023-07-09       19
# 3s90         Abgeschlossen         nein 2023-06-28        2
# ...                    ...          ...        ...      ...
# uP59      Erhebung_1_aktiv           ja 2023-10-02        5
# vPEr         Abgeschlossen           ja 2023-09-29       47
# wGQ8       Post_Erhebung_1           ja 2023-09-07       60
# xwB7               Dropout           ja 2023-07-24        4
# yv0Q      Erhebung_1_aktiv         nein 2023-09-25       12
#
# [69 rows x 9 columns]

# %%
grouped.groupby("status")["ema_id"].count()
# Out:
# status
# Abgeschlossen       15
# Dropout              3
# Erhebung_1_aktiv     7
# Post_Erhebung_1     44
# Name: ema_id, dtype: int64

# %%
grouped_active = grouped[~(grouped['status'] == "Abgeschlossen")]
grouped_active = grouped_active[~(grouped_active['status'] == "Dropout")]

# %% [markdown]
# ## GPS Data

# %%
datapath1 = datapath + f"export_tiki_{today}/"
filepath_1 = datapath1 + "epoch_part0001.csv"
filepath_2 = datapath1 + "epoch_part0002.csv"
filepath_3 = datapath1 + "epoch_part0003.csv"

# %%
df_1 = pd.read_csv(filepath_1, encoding= "latin-1")
df_2 = pd.read_csv(filepath_2, encoding= "latin-1")
df_3 = pd.read_csv(filepath_3, encoding= "latin-1")
# Out:
# /Users/leonahammelrath/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_location_1 = df_1[df_1.type.isin(["Latitude", "Longitude"])]
df_location_2 = df_2[df_2.type.isin(["Latitude", "Longitude"])]
df_location_3 = df_3[df_3.type.isin(["Latitude", "Longitude"])]

# %%
df_loc_complete = pd.concat([df_location_1, df_location_2, df_location_3])
df_loc_complete = df_loc_complete[["customer", "startTimestamp", "type", "doubleValue", 
                           "timezoneOffset"]]
df_loc_complete["customer"] = df_loc_complete.customer.str.split("@").str.get(0)
df_loc_complete["customer"] = df_loc_complete.customer.str[:4]

# %%
df_merged = pd.merge(df_loc_complete, grouped_active, on="customer")
df_merged["startTimestamp"] = (pd.to_datetime(df_merged["startTimestamp"],unit='ms'))
#df_merged_active = df_merged[~(df_merged['status'].isin(["Abgeschlossen", "Dropout"]))]

# %%
df_merged_active= df_merged.groupby("customer")[["ema_id","for_id","day","study_version","status","startTimestamp"]].max()

# %%
df_merged_active
# Out:
#            ema_id     for_id        day   study_version            status  \
# customer
# 0ePW      EMA4006   FOR14007 2023-09-21            Lang   Post_Erhebung_1
# 0xWn      EMA2004   FOR12003 2023-10-02            Lang   Post_Erhebung_1
# 1rfO      EMA3006   FOR13002 2023-07-05  Lang (Wechsel)   Post_Erhebung_1
# 4HX0      EMA1015  FOR11024  2023-09-29            Lang   Post_Erhebung_1
# 5BAw      EMA4032  FOR14025  2023-10-02            Lang  Erhebung_1_aktiv
# 5Ger      EMA1020  FOR11036  2023-10-01            Kurz  Erhebung_1_aktiv
# 5MyR      EMA4026  FOR14022  2023-10-02            Lang   Post_Erhebung_1
# 7uRT      EMA4030  FOR14024  2023-10-01            Lang  Erhebung_1_aktiv
# 94FE      EMA2002   FOR12901 2023-10-02            Lang   Post_Erhebung_1
# AG7S      EMA1014   FOR11022 2023-10-02            Lang   Post_Erhebung_1
# BdSf      EMA2001   FOR12902 2023-10-02            Lang   Post_Erhebung_1
# CySo      EMA4012  FOR14014  2023-09-28            Lang   Post_Erhebung_1
# D2mZ      EMA1019  FOR11030  2023-10-02            Lang   Post_Erhebung_1
# GjiG      EMA2009  FOR12005  2023-10-01            Lang   Post_Erhebung_1
# JIhV      EMA1009   FOR11019 2023-10-02  Lang (Wechsel)   Post_Erhebung_1
# K0go      EMA1012  FOR11016  2023-09-19            Lang   Post_Erhebung_1
# L9hp      EMA3014   FOR13010 2023-10-01            Lang   Post_Erhebung_1
# MDgC      EMA4020   FOR14019 2023-10-02            Lang   Post_Erhebung_1
# MJFT      EMA4004   FOR14005 2023-10-02            Lang   Post_Erhebung_1
# MYAi      EMA4028   FOR14023 2023-10-02            Lang   Post_Erhebung_1
# Mkds      EMA4013   FOR14016 2023-10-01  Lang (Wechsel)   Post_Erhebung_1
# Snml      EMA4034  FOR14026  2023-10-02            Lang  Erhebung_1_aktiv
# asYV      EMA1008  FOR11011  2023-09-22            Lang   Post_Erhebung_1
# dT0F      EMA3003   FOR13008 2023-10-01            Lang   Post_Erhebung_1
# dZYU      EMA4008   FOR14010 2023-09-30            Lang   Post_Erhebung_1
# f1J2      EMA4018   FOR14017 2023-10-02            Lang   Post_Erhebung_1
# fjGD      EMA3007   FOR13011 2023-10-02            Lang   Post_Erhebung_1
# gfo4      EMA4003   FOR14002 2023-09-27  Lang (Wechsel)   Post_Erhebung_1
# hIhW      EMA2008  FOR12008  2023-10-02            Lang   Post_Erhebung_1
# kH1x      EMA4002   FOR14003 2023-09-13            Lang   Post_Erhebung_1
# kVhY      EMA1003   FOR11001 2023-09-27            Lang   Post_Erhebung_1
# lLs0      EMA4014   FOR14015 2023-09-30            Lang   Post_Erhebung_1
# lg1t      EMA4038  FOR14029  2023-10-02            Lang  Erhebung_1_aktiv
# nrqZ      EMA1017  FOR11026  2023-09-27            Lang   Post_Erhebung_1
# p4A1      EMA2013  FOR12010  2023-09-30            Lang   Post_Erhebung_1
# pnfK      EMA1023   FOR11035 2023-10-02            Lang   Post_Erhebung_1
# uGoA      EMA3012   FOR13005 2023-10-02            Lang   Post_Erhebung_1
# uP59      EMA4036  FOR14027  2023-10-02            Lang  Erhebung_1_aktiv
# yv0Q      EMA3016  FOR13012  2023-09-25            Lang  Erhebung_1_aktiv
#
#               startTimestamp
# customer
# 0ePW     2023-10-01 23:46:46
# 0xWn     2023-09-30 22:47:15
# 1rfO     2023-10-01 19:55:31
# 4HX0     2023-09-26 12:30:49
# 5BAw     2023-10-01 19:31:55
# 5Ger     2023-10-01 14:02:50
# 5MyR     2023-10-01 18:29:53
# 7uRT     2023-09-22 20:58:55
# 94FE     2023-10-01 14:28:14
# AG7S     2023-09-28 13:48:39
# BdSf     2023-10-01 22:18:04
# CySo     2023-09-26 12:47:10
# D2mZ     2023-10-01 21:43:19
# GjiG     2023-10-01 15:40:09
# JIhV     2023-10-01 19:33:40
# K0go     2023-09-19 06:17:59
# L9hp     2023-09-24 08:07:24
# MDgC     2023-09-30 16:02:25
# MJFT     2023-10-01 18:39:38
# MYAi     2023-10-01 21:04:25
# Mkds     2023-09-29 09:15:06
# Snml     2023-10-01 15:23:19
# asYV     2023-09-05 07:14:38
# dT0F     2023-09-30 17:49:22
# dZYU     2023-10-01 16:36:41
# f1J2     2023-10-01 16:07:16
# fjGD     2023-09-30 08:31:34
# gfo4     2023-10-01 10:17:34
# hIhW     2023-09-23 18:46:15
# kH1x     2023-09-30 15:01:30
# kVhY     2023-06-01 10:50:00
# lLs0     2023-09-25 16:18:43
# lg1t     2023-10-02 00:11:27
# nrqZ     2023-10-01 09:07:14
# p4A1     2023-09-30 14:35:48
# pnfK     2023-09-29 16:18:04
# uGoA     2023-08-09 08:55:01
# uP59     2023-10-01 13:48:35
# yv0Q     2023-09-25 00:20:40

# %%
df_merged_active.loc[(df_merged_active.startTimestamp < week_ago) & (df_merged_active.day < week_ago)]
# Out:
#            ema_id     for_id        day study_version           status  \
# customer
# K0go      EMA1012  FOR11016  2023-09-19          Lang  Post_Erhebung_1
# asYV      EMA1008  FOR11011  2023-09-22          Lang  Post_Erhebung_1
#
#               startTimestamp
# customer
# K0go     2023-09-19 06:17:59
# asYV     2023-09-05 07:14:38

# %%
# no gpspd
df_merged_active.loc[(df_merged_active.startTimestamp < week_ago) & (df_merged_active.day < week_ago)]["for_id"].tolist()
# Out:
# ['FOR11016 ', 'FOR11011 ']

# %%
# no gps
df_merged_active.loc[(df_merged_active.startTimestamp < week_ago) & (df_merged_active.day > week_ago)]
# Out:
#            ema_id     for_id        day study_version            status  \
# customer
# 7uRT      EMA4030  FOR14024  2023-10-01          Lang  Erhebung_1_aktiv
# L9hp      EMA3014   FOR13010 2023-10-01          Lang   Post_Erhebung_1
# hIhW      EMA2008  FOR12008  2023-10-02          Lang   Post_Erhebung_1
# kVhY      EMA1003   FOR11001 2023-09-27          Lang   Post_Erhebung_1
# uGoA      EMA3012   FOR13005 2023-10-02          Lang   Post_Erhebung_1
#
#               startTimestamp
# customer
# 7uRT     2023-09-22 20:58:55
# L9hp     2023-09-24 08:07:24
# hIhW     2023-09-23 18:46:15
# kVhY     2023-06-01 10:50:00
# uGoA     2023-08-09 08:55:01

# %%
# no gps
df_merged_active.loc[(df_merged_active.startTimestamp < week_ago) & (df_merged_active.day > week_ago)]["for_id"].tolist()
# Out:
# ['FOR14024 ', 'FOR13010', 'FOR12008 ', 'FOR11001', 'FOR13005']

# %%
# no gps
df_merged_active.loc[(df_merged_active.startTimestamp < week_ago) & (df_merged_active.day > week_ago)]["ema_id"].tolist()
# Out:
# ['EMA4030', 'EMA3014', 'EMA2008', 'EMA1003', 'EMA3012']

# %%
# no pd
df_merged_active.loc[(df_merged_active.startTimestamp > week_ago) & (df_merged_active.day < week_ago)]
# Out:
#            ema_id    for_id        day   study_version           status  \
# customer
# 0ePW      EMA4006  FOR14007 2023-09-21            Lang  Post_Erhebung_1
# 1rfO      EMA3006  FOR13002 2023-07-05  Lang (Wechsel)  Post_Erhebung_1
# kH1x      EMA4002  FOR14003 2023-09-13            Lang  Post_Erhebung_1
#
#               startTimestamp
# customer
# 0ePW     2023-10-01 23:46:46
# 1rfO     2023-10-01 19:55:31
# kH1x     2023-09-30 15:01:30

# %%
# no pd
df_merged_active.loc[(df_merged_active.startTimestamp > week_ago) & (df_merged_active.day < week_ago)]["for_id"].tolist()
# Out:
# ['FOR14007', 'FOR13002', 'FOR14003']

# %% [markdown]
# ## Missing data

# %%
list_1 = df_active.customer.tolist()
list_2 = df_complete.customer.unique().tolist()
set(list_1) - set(list_2)
# Out:
# {'Nuz5', 'x3TJ'}
